# %%
from pathlib import Path

SAVE_PATH = Path.cwd()/ "Trained_models" / "multi_big.pth"
print(SAVE_PATH)
# Out:
# /zhome/d2/4/167803/Desktop/Deep_project/02456-final-project/Model/Trained_models/multi_big.pth
